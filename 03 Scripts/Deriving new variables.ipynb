# %% [markdown]
# 1. Importing Libraries

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import os

# %%
# Creating Path
path = r'/Users/mac/Documents/01-2022 Instacart Basket Analysis'

# %% [markdown]
# 2. Importing Merged Data

# %%
#Importing Merged Data
df_ords_prods_merged = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.csv'), index_col = False)

# %%
# Creating a subset
df_ords_prods_merged = df_ords_prods_merged[:1000000]

# %% [markdown]
# 3. Defining Function

# %%
# Defining function
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %% [markdown]
# 4. Applying the function

# %%
# Apply the function
df_ords_prods_merged['price_range'] = df_ords_prods_merged.apply(price_label, axis=1)

# %%
#Count of Data
df_ords_prods_merged['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
# Checking description
df_ords_prods_merged['prices'].max()
# Out:
# 14.8

# %% [markdown]
# 5. Using the If-Statement with the loc Function

# %%
# Applying the function
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
# Applying the function
df_ords_prods_merged.loc[(df_ords_prods_merged['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
# Applying the function
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
# Checking description
df_ords_prods_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range_loc, dtype: int64

# %% [markdown]
# 6. Using the If-Statement with the for_loop Function

# %%
# Identifying days orders take place
df_ords_prods_merged['order_dow'].value_counts(dropna = False)
# Out:
# 1    189421
# 0    184410
# 2    133958
# 5    130683
# 6    124839
# 3    119801
# 4    116888
# Name: order_dow, dtype: int64

# %%
# Running the loop
result = []

for value in df_ords_prods_merged["order_dow"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
# Identifying result
df_ords_prods_merged['busiest_day'] = result

# %%
# Identifying busiest days
df_ords_prods_merged['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    698702
# Busiest day       184410
# Least busy        116888
# Name: busiest_day, dtype: int64

# %% [markdown]
# Question 2 - Updated result

# %%
# Identifying 2 busiest an 2 slowest days
second_result = []

for value in df_ords_prods_merged["order_dow"]:
  if value == 0:
    second_result.append("Busiest_days")
  elif value == 0 or value == 1:
    second_result.append("Busiest_days")
  elif value == 3:
    second_result.append("Slowest_days")
  elif value ==4:
    second_result.append("Slowest_days")
  else:
    second_result.append("Regularly busy")

# %%
second_result
# Out:
# ['Regularly busy',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Regularly busy',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Slowest_days',
#  'Busiest_days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest_days',
#  'Busiest_days',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest_days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest_days',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest_days',
#  'Regularly busy',
#  'Slowest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Regularly busy',
#  'Slowest_days',
#  'Slowest_days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest_days',
#  'Busiest_days',
#  'Regularly busy',
#  'Busiest_days',
#  'Busiest_days',
# ...

# %%
df_ords_prods_merged['Busiest_day'] = second_result

# %%
df_ords_prods_merged['Busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    389480
# Busiest_days      373831
# Slowest_days      236689
# Name: Busiest_day, dtype: int64

# %% [markdown]
# #

# %% [markdown]
# Question 4

# %%
# Identifying busiest hours of day
df_ords_prods_merged['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    90492
# 11    85835
# 9     84211
# 14    81965
# 15    81388
# 13    81377
# 12    79248
# 16    76499
# 17    60697
# 8     57772
# 18    46755
# 19    35989
# 7     29181
# 20    28213
# 21    23796
# 22    19103
# 23    11911
# 6      8827
# 0      6451
# 1      3163
# 5      2552
# 2      1865
# 4      1427
# 3      1283
# Name: order_hour_of_day, dtype: int64

# %%
# Labeling periods
new_result = []

for value in df_ords_prods_merged["order_hour_of_day"]:
  if value >10 & value <=13:
    new_result.append("Most_orders")
  elif value <=5:
    new_result.append("Fewest_orders")
  else:
    new_result.append("Average_orders")

# %%
new_result
# Out:
# ['Average_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Average_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Average_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Average_orders',
#  'Average_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Average_orders',
#  'Average_orders',
#  'Average_orders',
#  'Most_orders',
#  'Most_orders',
#  'Average_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Average_orders',
#  'Average_orders',
#  'Average_orders',
#  'Average_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Average_orders',
#  'Most_orders',
#  'Most_orders',
#  'Average_orders',
#  'Most_orders',
#  'Average_orders',
#  'Most_orders',
# ...

# %%
# Creating new column - 'Busiest_period_of_day'
df_ords_prods_merged['Busiest_period_of_day'] = new_result

# %%
# Frequency
df_ords_prods_merged['Busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Most_orders       843420
# Average_orders    148264
# Fewest_orders       8316
# Name: Busiest_period_of_day, dtype: int64

# %% [markdown]
# Exporting data

# %%
# Export data to pkl

df_ords_prods_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'df_orders_products_merged.pkl'))

# %%
# Export data to csv

df_ords_prods_merged.to_csv(os.path.join(path, '02 Data','Prepared Data', 'df_orders_products_merged.csv'))
