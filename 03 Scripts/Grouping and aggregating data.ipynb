# %% [markdown]
# 1. Importing Libraries

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import os

# %%
# Creating Path
path = r'/Users/mac/Documents/01-2022 Instacart Basket Analysis'

# %% [markdown]
# 2. Importing Merged Data

# %%
#Importing Merged Data
ords_prods_merge = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'df_orders_products_merged.csv'), index_col = False)

# %%
# Creating a subset
df = ords_prods_merge[:1000000]

# %%
# Checking the first 5 rows
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0_x  order_id  user_id eval_set  \
# 0           0             0             0   2539329        1    prior
# 1           1             1             5   2398795        1    prior
# 2           2             2            11    473747        1    prior
# 3           3             3            16   2254736        1    prior
# 4           4             4            21    431534        1    prior
#
#    order_number  order_dow  order_hour_of_day  days_since_prior_order  ...  \
# 0             1          2                  8                     NaN  ...
# 1             2          3                  7                    15.0  ...
# 2             3          3                 12                    21.0  ...
# 3             4          4                  7                    29.0  ...
# 4             5          4                 15                    28.0  ...
#
#    Unnamed: 0_y  product_name  aisle_id department_id  prices  \
# ...

# %%
# Checking the shape
df.shape
# Out:
# (1000000, 24)

# %% [markdown]
# 3. Grouping Data with pandas

# %%
# Grouping by product_name
df.groupby('product_name')

# %%
# Aggregating each group
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
# Performing multiple aggregations
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %% [markdown]
# 4. Aggregating Data with Transform

# %%
# Creating max order column
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     Unnamed: 0  Unnamed: 0.1  Unnamed: 0_x  order_id  user_id eval_set  \
# 0            0             0             0   2539329        1    prior
# 1            1             1             5   2398795        1    prior
# 2            2             2            11    473747        1    prior
# 3            3             3            16   2254736        1    prior
# 4            4             4            21    431534        1    prior
# 5            5             5            29   3367565        1    prior
# 6            6             6            33    550135        1    prior
# 7            7             7            39   3108588        1    prior
# 8            8             8            47   2295261        1    prior
# 9            9             9            50   2550362        1    prior
# 10          10            10          1391   2968173       15    prior
# 11          11            11          1402   1870022       15    prior
# ...

# %%
# Displaying max rows
pd.options.display.max_rows = None

# %%
ords_prods_merge.head(100)
# Out:
#     Unnamed: 0  Unnamed: 0.1  Unnamed: 0_x  order_id  user_id eval_set  \
# 0            0             0             0   2539329        1    prior
# 1            1             1             5   2398795        1    prior
# 2            2             2            11    473747        1    prior
# 3            3             3            16   2254736        1    prior
# 4            4             4            21    431534        1    prior
# 5            5             5            29   3367565        1    prior
# 6            6             6            33    550135        1    prior
# 7            7             7            39   3108588        1    prior
# 8            8             8            47   2295261        1    prior
# 9            9             9            50   2550362        1    prior
# 10          10            10          1391   2968173       15    prior
# 11          11            11          1402   1870022       15    prior
# ...

# %% [markdown]
# 5. Deriving columns with loc

# %%
# Assigning loyalty label - loyal customer
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
# Assigning loyalty label - Regular customer
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
# Assigning loyalty label - New customer
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    463844
# Loyal customer      335086
# New customer        201070
# Name: loyalty_flag, dtype: int64
